# %% [markdown]
# Use the data in OVRDUE.csv file. We are interested in estimating the average amount of money owed by a bank’s delinquent debtors. We have collected a random sample of 100 observations.
# - Construct a 95% confidence interval for the average amount of money owed in the population:
#     - find the estimate for population standard deviation using the sample
#     - use the obtained estimate to find the standard deviation for sample average
#     - use the obtained information to find either z-scores or normal distribution quantiles
#
# It was previously believed that the average amount of money owed is about $200. Do you think it can be the case?

# %% [markdown]
# First, we import the necessary packages and check the directory:

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import os
os.getcwd() #check the current directory
# Out:
# 'C:\\Users\\voro5912\\OneDrive - University of St. Thomas\\BUAN640Yulia\\code'

# %%
# Load the dataset
dataset = pd.read_csv('data/OVRDUE.csv')

# Extract the AMOUNT column
amount = dataset['AMOUNT']

# %%
print(amount)
# Out:
# 0     195
# 1     243
# 2     132
# 3     133
# 4     209
#      ...
# 95    157
# 96    219
# 97     77
# 98    171
# 99    280
# Name: AMOUNT, Length: 100, dtype: int64

# %%
np.median(amount)
# Out:
# np.float64(222.0)
